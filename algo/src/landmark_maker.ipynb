# %% [markdown]
# ## Extract landmarks from json

# %%
import os
import json
import pandas as pd
from pandas import json_normalize

data_file_path = '../data/landmarks'


# Initialize an empty list to hold data frames
dfs = []

# List all files in the directory 'landmarks'
for filename in os.listdir(data_file_path):
    # Check if the file is a JSON file
    if filename.endswith('.json'):
        # Open the JSON file
        with open(os.path.join(data_file_path, filename), 'r') as f:
            # Load the JSON content
            content = json.load(f)
            
            # Check if 'elements' key exists in the JSON content
            if 'elements' in content:
                # Use json_normalize to flatten the nested 'tags' dictionary
                df = json_normalize(content['elements'], sep='_')
                
                # Append the data frame to the list
                dfs.append(df)

# Concatenate all data frames in the list into a single data frame
final_df = pd.concat(dfs, ignore_index=True)

# Save the final data frame
final_df.to_csv('./landmarks.csv', index=False)

# %% [markdown]
# ## Clean up landmarks by deduplication and null value from lat, lon and tag_name

# %%
# tags_name, lat and lon should not be null or nan

final_df = final_df[final_df['lat'].notnull()]
final_df = final_df[final_df['lon'].notnull()]
final_df = final_df[final_df['tags_name'].notnull()]

# remove duplicates
final_df.drop_duplicates(subset=['tags_name', 'lat', 'lon'], inplace=True)

final_df.reset_index(drop=True, inplace=True)

# %%
final_df.to_csv('./landmarks_clean.csv', index=False)

# %%
final_df
# Out:
#      type           id        lat        lon tags_amenity  \
# 0    node   1398437051  27.668738  85.538153         cafe
# 1    node   1769321635  27.630180  85.524165         cafe
# 2    node   1819665900  27.618443  85.538343         cafe
# 3    node   3986718694  27.632663  85.517836         cafe
# 4    node   4327779391  27.621901  85.538583         cafe
# ..    ...          ...        ...        ...          ...
# 489  node  10889516105  27.641784  85.477396   restaurant
# 490  node  10889516205  27.620168  85.553375   restaurant
# 491  node  10889581105  27.642719  85.469714   restaurant
# 492  node  10943772558  27.617516  85.538309   restaurant
# 493  node   1833834929  27.629964  85.523287          atm
#
#                          tags_cuisine  \
# 0    regional;noodles;snacks;teahouse
# 1                                 NaN
# 2                                 NaN
# 3                           ice_cream
# 4                                 NaN
# ..                                ...
# 489                               NaN
# 490                               NaN
# 491                               NaN
# 492                               NaN
# 493                               NaN
#
#                                     tags_name            tags_source  \
# 0                                    Teahouse  Garmin Orgeon 450 GPS
# 1                              New Bhomi Cafe                    NaN
# 2                           KU Fast Food Cafe                    NaN
# 3                           Everest ice cream                    NaN
# 4                                  Durga cafe                    NaN
# ..                                        ...                    ...
# 489  The Burger House & Crunchy Fried Chicken                    NaN
# 490                         Fire n Wood Pizza                    NaN
# 491                               Daura Chulo                    NaN
# 492                        Anisha bhansa ghar                    NaN
# 493                     Nepal Investment Bank                    NaN
#
#           tags_addr:city tags_addr:street  ... tags_capacity tags_access  \
# 0                    NaN              NaN  ...           NaN         NaN
# 1                    NaN              NaN  ...           NaN         NaN
# 2                    NaN              NaN  ...           NaN         NaN
# 3    Banepa Municipality       Aananda M.  ...           NaN         NaN
# 4                    NaN              NaN  ...           NaN         NaN
# ..                   ...              ...  ...           ...         ...
# 489                  NaN              NaN  ...           NaN         NaN
# 490                  NaN              NaN  ...           NaN         NaN
# 491                  NaN              NaN  ...           NaN         NaN
# 492                  NaN              NaN  ...           NaN         NaN
# 493                  NaN              NaN  ...           NaN         NaN
#
#     tags_parking tags_covered tags_fee tags_supervised tags_surface  \
# 0            NaN          NaN      NaN             NaN          NaN
# 1            NaN          NaN      NaN             NaN          NaN
# 2            NaN          NaN      NaN             NaN          NaN
# 3            NaN          NaN      NaN             NaN          NaN
# 4            NaN          NaN      NaN             NaN          NaN
# ..           ...          ...      ...             ...          ...
# 489          NaN          NaN      NaN             NaN          NaN
# 490          NaN          NaN      NaN             NaN          NaN
# 491          NaN          NaN      NaN             NaN          NaN
# 492          NaN          NaN      NaN             NaN          NaN
# 493          NaN          NaN      NaN             NaN          NaN
#
#     tags_description tags_delivery tags_drive_through
# 0                NaN           NaN                NaN
# 1                NaN           NaN                NaN
# 2                NaN           NaN                NaN
# 3                NaN           NaN                NaN
# 4                NaN           NaN                NaN
# ..               ...           ...                ...
# 489              NaN           NaN                NaN
# 490              NaN           NaN                NaN
# 491              NaN           NaN                NaN
# 492              NaN           NaN                NaN
# 493              NaN           NaN                NaN
#
# [494 rows x 76 columns]
