# %%
from matplotlib import pyplot as plt
import pandas as pd

# Load the comparative metrics
comparison_df = pd.read_csv('comparison_metrics.csv')


plt.figure(figsize=(10, 6))
x = comparison_df['Metric']
plt.bar(x, comparison_df['Landmark-Based'], width=0.4, label='Landmark-Based', align='center')
plt.bar(x, comparison_df['Traditional'], width=0.4, label='Traditional', align='edge')
plt.title("Comparison of Routing Metrics")
plt.xlabel("Metric")
plt.ylabel("Value")
plt.legend()
plt.xticks(rotation=45)
plt.show()

# %%
comparison_df
# Out:
#                 Metric  Landmark-Based  Traditional
# 0  Average Path Length       45.155758    71.295130
# 1  Average Travel Time      420.668764   631.889019
# 2         Success Rate        0.712000     0.999900

# %%
[1] 3469590


htop -p 3469590
